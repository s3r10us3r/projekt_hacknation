# %%
from transformers import  AutoProcessor, AutoModelForImageTextToText, AutoModelForSeq2SeqLM, AutoTokenizer, BitsAndBytesConfig
import torch

# %%
LOCAL_CACHE = "D:/Hackathon/notebook"

VLM_MODEL_PATH = "HuggingFaceTB/SmolVLM2-2.2B-Instruct"
TRANSLATOR_PATH = "facebook/nllb-200-distilled-600M"

TARGET_LANG = "pol_Latn"
SOURCE_LANG = "eng_Latn"

DESC_PROMPT = "Can you describe with details how the lost item shown on this image looks like? Focus on the item, do not describe the background."
DESC_MAX_RESPONSE_LENTGH = 512
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
dtype = torch.bfloat16

CLASSES = 'DOCUMENTS_AND_WALLETS, ELECTRONICS, CLOTHES_AND_ACCESSORIES, KEYS, JEWELRY_AND_WATCHES, CASH, OTHERS'
classes_insert = str(CLASSES.split(', '))
CL_PROMPT = f"A lost item has been found. Your job is to determine what kind of object is it. The only allowed categories are {classes_insert}. Reply only with class index from the list, starting from index 0."
CL_MAX_RESPONSE_LENTGH = 32
print(CL_PROMPT)

CL_PROMPT = '''
Classify this lost item into one of the categories below. Reply only with the number:

0 – Documents/Wallets
1 – Electronics
2 – Clothes/Accessories
3 – Keys
4 – Jewelry/Watches
5 – Cash
6 – Other
'''
print(CL_PROMPT)
# Out:
# cuda
# A lost item has been found. Your job is to determine what kind of object is it. The only allowed categories are ['DOCUMENTS_AND_WALLETS', 'ELECTRONICS', 'CLOTHES_AND_ACCESSORIES', 'KEYS', 'JEWELRY_AND_WATCHES', 'CASH', 'OTHERS']. Reply only with class index from the list, starting from index 0.
#
# Classify this lost item into one of the categories below. Reply only with the number:
#
# 0 – Documents/Wallets
# 1 – Electronics
# 2 – Clothes/Accessories
# 3 – Keys
# 4 – Jewelry/Watches
# 5 – Cash
# 6 – Other

# %%
processor = AutoProcessor.from_pretrained(VLM_MODEL_PATH, cache_dir=LOCAL_CACHE)

vlm_model = AutoModelForImageTextToText.from_pretrained(
    VLM_MODEL_PATH,
    dtype=dtype,
).to(device)
# Out:
# Fetching 2 files: 100%|███████████████████████████████████████████████| 2/2 [05:19<00:00, 159.57s/it]
# Loading checkpoint shards: 100%|███████████████████████████████████████| 2/2 [00:19<00:00,  9.94s/it]

# %%
def inference_vlm(image_path: str, prompt: str, max_length: int):
    messages = [
        {
            "role": "user",
            "content": [
                {"type": "image", "path": image_path},
                {"type": "text", "text": prompt},
            ],
        }
    ]

    inputs = processor.apply_chat_template(
        messages,
        add_generation_prompt=True,
        tokenize=True,
        return_dict=True,
        return_tensors="pt",
    ).to(vlm_model.device)

    generated_ids = vlm_model.generate(
        **inputs,
        do_sample=False,
        max_new_tokens=max_length,
    )

    prompt_len = inputs["input_ids"].shape[-1]
    gen_only = generated_ids[:, prompt_len:]

    output = processor.batch_decode(
        gen_only,
        skip_special_tokens=True,
    )[0].strip()
    return output

# %%
inference_vlm("rower.png", DESC_PROMPT, DESC_MAX_RESPONSE_LENTGH)
# Out:
# 'The lost item is a black bicycle with a black seat, black handlebars, and black tires. It has a black frame and a black basket on the back. The bicycle is standing on a dirt path in a forest.'

# %%
from langchain_openai import ChatOpenAI

api_key = ""
base_url = "https://apim-pllum-tst-pcn.azure-api.net/vllm/v1"
model_name = "CYFRAGOVPL/pllum-12b-nc-chat-250715"

llm = ChatOpenAI(
    model=model_name,
    api_key="EMPTY",              # required but unused
    base_url=base_url,            # correct parameter name
    temperature=0.7,
    max_tokens=300,
    default_headers={
        "Ocp-Apim-Subscription-Key": api_key
    }
)

response = llm.invoke("Prztłumacz na polski. Zwróć w formacie json {}: The lost item is a black bicycle with a black seat, black handlebars, and black tires. It has a black frame and a black basket on the back. The bicycle is standing on a dirt path in a forest.")
print(response.content)
# Out:
# Przedstawiam tekst przetłumaczony na polski:
#
# {
#   "Polish": "Zgubiony przedmiot to czarny rower z czarnym siodełkiem, czarną kierownicą i czarnymi oponami. Ma czarną ramę i czarny koszyk z tyłu. Rower stoi na ścieżce w lesie."
# }

# %%
# !pip install langchain-openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-openai in c:\users\micha\appdata\roaming\python\python312\site-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langchain-openai) (1.1.1)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langchain-openai) (2.9.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.4.56)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (2.10.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (4.12.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\micha\appdata\roaming\python\python312\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (2.32.3)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\micha\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in c:\users\micha\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (4.7.0)
# Requirement already satisfied: certifi in c:\users\micha\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\micha\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in c:\users\micha\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\micha\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\micha\appdata\roaming\python\python312\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\micha\appdata\roaming\python\python312\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\micha\appdata\roaming\python\python312\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\micha\appdata\roaming\python\python312\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\micha\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\micha\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain-openai) (2.27.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\micha\appdata\roaming\python\python312\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\micha\appdata\roaming\python\python312\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\micha\appdata\roaming\python\python312\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (2.3.0)
# Requirement already satisfied: colorama in c:\users\micha\appdata\roaming\python\python312\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
